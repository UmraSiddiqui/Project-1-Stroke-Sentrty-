# %%
import pandas as pd

# %%
dataframe3 = pd.read_csv("heart_2020_cleaned.csv")

# %%
dataframe3.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# # checking for missing values

# %% [markdown]
# <font color=red>You missed the parenthesis here in sum i.e. sum() </font>

# %%
#dataframe.isnull().sum  # you missed parenthesis in sum i.e. sum()

# %%
dataframe3.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
dataframe3.shape
# Out:
# (319795, 18)

# %%
dataframe3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %% [markdown]
# ## checking for outliers

# %%
dataframe3.describe(percentiles=[.25, .5, .75, .90, .95, .99])
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# 90%        36.490000        14.00000      15.000000       8.000000
# 95%        40.180000        30.00000      30.000000       9.000000
# 99%        48.660000        30.00000      30.000000      12.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# <font color=red>Already you checked for missing value, this is duplicate </font>

# %%
round(100* dataframe3.isnull().sum()/len(dataframe3.index),2)
# Out:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# PhysicalHealth      0.0
# MentalHealth        0.0
# DiffWalking         0.0
# Sex                 0.0
# AgeCategory         0.0
# Race                0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# KidneyDisease       0.0
# SkinCancer          0.0
# dtype: float64

# %% [markdown]
# hurray! no missing values

# %% [markdown]
# <font color=red>On what basis did you drop these columns? Did you try checking correlation? </font>

# %%
#dataframe3 = dataframe.drop(columns = ['Asthma' , 'KidneyDisease','SkinCancer'])

# %%
dataframe3
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# <font color=red>Before creating dummies make sure to check all possible values using value_counts </font>

# %%
dataframe3["AgeCategory"].value_counts()
# Out:
# AgeCategory
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: count, dtype: int64

# %%
dataframe3["Race"].value_counts()
# Out:
# Race
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: count, dtype: int64

# %%
dataframe3["GenHealth"].value_counts()
# Out:
# GenHealth
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: count, dtype: int64

# %%
dataframe_dummies1 = pd.get_dummies(dataframe3[['AgeCategory','Race','GenHealth']], drop_first=True)

# %%
#dataframe_dummies2 = pd.get_dummies(dataframe3[['AgeCategory','Race','GenHealth']])

# %%
#dataframe_dummies2.head()

# %%
dataframe_dummies1.head()
# Out:
#    AgeCategory_25-29  AgeCategory_30-34  AgeCategory_35-39  AgeCategory_40-44  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False               True
#
#    AgeCategory_45-49  AgeCategory_50-54  AgeCategory_55-59  AgeCategory_60-64  \
# 0              False              False               True              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
# ...

# %%
gender = {'Female': 0 , 'Male': 1}
dataframe3['Sex'] = dataframe3['Sex'].map(gender)

# %%
dataframe3
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking  Sex  AgeCategory      Race Diabetic  \
# ...

# %%
variables = ['HeartDisease','Smoking','AlcoholDrinking','Stroke','DiffWalking','PhysicalActivity',\
             'Diabetic','Asthma','KidneyDisease','SkinCancer']

# %%
def mapping(x):
    return x.map({'Yes':1 ,'No':0})

# %%
dataframe3[variables] = dataframe3[variables].apply(mapping)

# %%
dataframe3
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
# ...

# %%
#dataframe3.apply(lambda x: len(x.unique()))

# %%
#dataframe3.columns

# %%
dataframe3 = pd.concat([dataframe3,dataframe_dummies1] , axis=1)

# %%
dataframe3.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  ... AgeCategory_80 or older  \
# 0          30.0            0    0        55-59  ...                   False
# 1           0.0            0    0  80 or older  ...                    True
# 2          30.0            0    1        65-69  ...                   False
# 3           0.0            0    0        75-79  ...                   False
# 4           0.0            1    0        40-44  ...                   False
#
#    Race_Asian  Race_Black Race_Hispanic  Race_Other  Race_White  \
# ...

# %% [markdown]
# repeated columns are 'Sex','AgeCategory','Race','GenHealth'

# %% [markdown]
# # drop the 'Sex','AgeCategory','Race','GenHealth' columns

# %%
dataframe3.drop(columns = ['AgeCategory','Race','GenHealth'],inplace = True)

# %%
dataframe3.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'Diabetic',
#        'PhysicalActivity', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'AgeCategory_25-29', 'AgeCategory_30-34',
#        'AgeCategory_35-39', 'AgeCategory_40-44', 'AgeCategory_45-49',
#        'AgeCategory_50-54', 'AgeCategory_55-59', 'AgeCategory_60-64',
#        'AgeCategory_65-69', 'AgeCategory_70-74', 'AgeCategory_75-79',
#        'AgeCategory_80 or older', 'Race_Asian', 'Race_Black', 'Race_Hispanic',
#        'Race_Other', 'Race_White', 'GenHealth_Fair', 'GenHealth_Good',
#        'GenHealth_Poor', 'GenHealth_Very good'],
#       dtype='object')

# %%
dataframe3.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  Diabetic  ...  AgeCategory_80 or older  \
# 0          30.0            0    0       1.0  ...                    False
# 1           0.0            0    0       0.0  ...                     True
# 2          30.0            0    1       1.0  ...                    False
# 3           0.0            0    0       0.0  ...                    False
# 4           0.0            1    0       0.0  ...                    False
#
#    Race_Asian  Race_Black  Race_Hispanic  Race_Other  Race_White  \
# ...

# %% [markdown]
#  we have no missing values, now we can perform train test split

# %%
dataframe3.shape
# Out:
# (319795, 36)

# %%
dataframe3['Stroke']
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 319790    0
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: Stroke, Length: 319795, dtype: int64

# %% [markdown]
# # checking the correlations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (20,10))
sns.heatmap(dataframe3.corr(), annot = True)
# Out:
# <Axes: >

# %%
dataframe3.drop(columns=["Race_Hispanic","Race_Black"], inplace=True)

# %%
dataframe3.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'Diabetic',
#        'PhysicalActivity', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'AgeCategory_25-29', 'AgeCategory_30-34',
#        'AgeCategory_35-39', 'AgeCategory_40-44', 'AgeCategory_45-49',
#        'AgeCategory_50-54', 'AgeCategory_55-59', 'AgeCategory_60-64',
#        'AgeCategory_65-69', 'AgeCategory_70-74', 'AgeCategory_75-79',
#        'AgeCategory_80 or older', 'Race_Asian', 'Race_Other', 'Race_White',
#        'GenHealth_Fair', 'GenHealth_Good', 'GenHealth_Poor',
#        'GenHealth_Very good'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
df = dataframe3[~(dataframe3["Diabetic"].isnull())]

# %%
df["Diabetic"].isnull().sum()
# Out:
# 0

# %%
#X = dataframe3.drop(columns=['Stroke'])
X = df.drop(columns=['Stroke'])

# %%
#y =  dataframe3['Stroke']
y =  df['Stroke']

# %%
X_train , X_test , y_train ,y_test = train_test_split(X,y,train_size = 0.7, test_size=0.3, random_state=100)

# %%
#dataframe3.head()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train[['BMI','PhysicalHealth','MentalHealth']]=scaler.fit_transform(X_train[['BMI','PhysicalHealth','MentalHealth']])

# %%
X_train
# Out:
#         HeartDisease       BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 251173             0 -0.829629        1                0       -0.423469
# 128723             0  0.276154        1                0       -0.423469
# 2446               0  0.883467        1                0        0.458800
# 4065               0  0.195705        0                0       -0.423469
# 133275             0 -0.624562        0                0       -0.423469
# ...              ...       ...      ...              ...             ...
# 68022              0 -1.463758        0                0       -0.423469
# 261502             0 -0.728673        1                0        3.357682
# 217154             0  0.148382        0                0       -0.423469
# 57806              0  0.119988        1                0        3.357682
# 309461             0  0.137339        0                0       -0.297431
#
#         MentalHealth  DiffWalking  Sex  Diabetic  PhysicalActivity  ...  \
# ...

# %%
stroke = sum(dataframe3['Stroke']/len(dataframe3['Stroke'].index))*100

# %% [markdown]
# ### <font color='red'>To DO Handle Class Imbalance</font>

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)

# %%
#dataframe3["Diabetic"]=  pd.to_numeric(dataframe3["Diabetic"])

# %%
#dataframe3[["Diabetic"]] = dataframe3[["Diabetic"]].apply(pd.to_numeric)

# %%
#dataframe3[~(dataframe3["Diabetic"].isnull())]["Diabetic"]

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn import metrics

# %%
len(y_pred)
# Out:
# 93137

# %%
len(y_train)
# Out:
# 217318

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9618518955946617

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'Diabetic',
#        'PhysicalActivity', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'AgeCategory_25-29', 'AgeCategory_30-34',
#        'AgeCategory_35-39', 'AgeCategory_40-44', 'AgeCategory_45-49',
#        'AgeCategory_50-54', 'AgeCategory_55-59', 'AgeCategory_60-64',
#        'AgeCategory_65-69', 'AgeCategory_70-74', 'AgeCategory_75-79',
#        'AgeCategory_80 or older', 'Race_Asian', 'Race_Other', 'Race_White',
#        'GenHealth_Fair', 'GenHealth_Good', 'GenHealth_Poor',
#        'GenHealth_Very good'],
#       dtype='object')

# %%
model = LogisticRegression(C=20,penalty='l2' )

# %%
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=20)

# %%
y_train_pred = model.predict(X_train)

# %%
metrics.accuracy_score(y_train,y_train_pred)
# Out:
# 0.9624421354880865

# %%
import pickle

# %%
import locale
locale.getpreferredencoding = lambda:"UTF-8"

# %%
mo = 'model/saved_model.sav'
file = open(mo, 'wb')
pickle.dump(df, file)
